# %%
import gensim
import nltk
import numpy as np
import pandas as pd

from gensim.models import Word2Vec
from nltk.data import find
import matplotlib
from sklearn.manifold import TSNE
import string
from urllib.request import urlopen
import nltk, re, pprint
from nltk import word_tokenize
from nltk import tokenize
from sklearn.cluster import KMeans
import matplotlib
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
# Out:
# C:\Users\Mike\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True)

# %%
word_pairs = [
              ('France', 'England') ,
              ('smaller', 'bigger'), 
              ('England', 'London'), 
              ('France', 'Rocket'), 
              ('big', 'bigger')
            ]

# %% [markdown]
# q1: Compute the cosine similarity

# %%
for pair in word_pairs:
    print(model.similarity(pair[0], pair[1]))
# Out:
# 0.39804946199997737
# 0.7302272087331374
# 0.43992858122481976
# 0.07114174367741377
# 0.6842385598892737

# %% [markdown]
# Q2 : Write an expression to extract the vector representations of the words (France, England, smaller, bigger, rocket, big).

# %%
for i in ('France', 'England', 'smaller', 'bigger', 'rocket', 'big'):
    print(model[i])
# Out:
# [ 4.85839844e-02  7.86132812e-02  3.24218750e-01  3.49121094e-02
#   7.71484375e-02  3.54003906e-02 -1.25976562e-01 -3.86718750e-01
#  -1.31835938e-01  2.91748047e-02 -1.44531250e-01 -1.42578125e-01
#   1.79687500e-01 -2.75390625e-01 -1.65039062e-01  9.32617188e-02
#   1.17187500e-01  1.82617188e-01  6.10351562e-02  1.14257812e-01
#   1.82617188e-01 -1.16699219e-01 -3.24707031e-02 -7.56835938e-02
#   9.64355469e-03  8.59375000e-02 -2.85156250e-01 -2.55859375e-01
#   3.01513672e-02  2.16796875e-01 -1.00097656e-01  2.85644531e-02
#  -2.81250000e-01 -8.39843750e-02 -2.02636719e-02 -1.96289062e-01
#  -4.78515625e-02  7.12890625e-02 -1.42578125e-01 -1.13525391e-02
#   1.16210938e-01  7.22656250e-02  1.47460938e-01  1.50390625e-01
#   1.40625000e-01  2.47070312e-01 -1.69921875e-01  7.76367188e-02
#  -5.44433594e-02  1.66992188e-01 -1.45507812e-01  2.12402344e-02
#  -7.51953125e-02  4.58984375e-02 -2.55859375e-01  1.49414062e-01
# ...

# %% [markdown]
# Q3: Repeat the exercise from Q1 by finding the euclidean distances between the word pairs.

# %%
for pair in word_pairs:
    print(pair[0], ", ", pair[1], ' = ', np.linalg.norm(model[pair[0]]-model[pair[1]]))
# Out:
# France ,  England  =  3.0151067
# smaller ,  bigger  =  1.8618743
# England ,  London  =  2.8752837
# France ,  Rocket  =  3.892071
# big ,  bigger  =  1.9586496

# %% [markdown]
# Q4: What is the relationship between the magnitude of individual vectors, the vectors themselves and the cosine distance for any pair of words. Choose any tuple in Q1 and provide your answer.

# %% [markdown]
# We know that semantic meaning is encoded in the vector (which consists of the direction and size). Looking at the word pairs it doesn't seem to look as if the size of the vector doesn't matter. Rather it is when we look at both aspects of a vector as a whole (ie. using cosine distance or adding subtracting vectors) when we are able to find words in different contexts. Interestingly, this is consistent with most neural net analyzed images, in which the cosine distance usually is what encodes allot more of the meaning.

# %% [markdown]
# Q5: Time to dabble with the power of Word2Vec. Find the 2 closest words for the following conditions:

# %%
print(model.most_similar(positive=["king"], negative=["queen"], topn=2))
# Out:
# [('Sultan', 0.2812919020652771), ('P._Calamos', 0.27442067861557007)]

# %%
print(model.most_similar(positive=["bigger","small"], negative=["big"], topn=2))
# Out:
# [('larger', 0.7402471899986267), ('smaller', 0.7329993844032288)]

# %%
print(model.most_similar(positive=["man","programmer"], negative=["woman"], topn=2))
# Out:
# [('programer', 0.5371963977813721), ('programmers', 0.5310999155044556)]

# %%
print(model.most_similar(positive=["school","shooting"], negative=["guns"], topn=2))
# Out:
# [('elementary', 0.5435296297073364), ('eighth_grade', 0.47330963611602783)]

# %%
print(model.most_similar(positive=["texas","milwaukee"], negative=["wisconsin"], topn=2))
# Out:
# [('houston', 0.5542162656784058), ('dallas', 0.5138501524925232)]

# %% [markdown]
# Q6: Using the vectors for the words in the Google News dataset, explore the semantic representation of these words through K-means clustering and explain your findings.

# %%
to_dict = model.index2word
gensimdict = np.zeros((len(to_dict), model.vector_size))
for index, word in enumerate(to_dict):
    gensimdict[index, :] += model[word]

# %%
df = pd.DataFrame(gensimdict)
dfsample = df.sample(100)

words = [to_dict[i] for i in dfsample.index]
print(words)
# Out:
#               0         1         2         3         4         5         6    \
# 2500359 -0.104004  0.092773  0.091797 -0.065918  0.089844  0.060791 -0.059082
# 2816090  0.018799 -0.053223  0.040283 -0.097656 -0.032227 -0.009644  0.017090
# 2603390 -0.020508  0.040771  0.038574  0.069824 -0.037598  0.041504  0.091309
# 658773  -0.016479  0.063965 -0.069336  0.003616  0.132812 -0.106445  0.027344
# 1821360 -0.090332 -0.002060  0.003647 -0.019897 -0.036133 -0.043701  0.174805
# 2150039 -0.067871  0.051758  0.040527  0.081543  0.003265 -0.052002 -0.085938
# 364385  -0.621094 -0.417969  0.071289 -0.023193  0.195312 -0.238281  0.205078
# 1507110  0.121582 -0.087402 -0.100586  0.018433  0.079102 -0.031250  0.056885
# 812951  -0.074707  0.073242 -0.130859  0.064453  0.041260 -0.156250  0.017578
# 131893  -0.314453 -0.632812 -0.019043 -0.119629  0.345703  0.000338 -0.112305
# 1442137 -0.077637 -0.190430  0.067871  0.062988  0.041016 -0.125977  0.088867
# ...

# %%
norm = TSNE(n_components=2).fit_transform(dfsample)

# %%
ks = []
for k in range(2,12):
    kmeans = KMeans(n_clusters=k, random_state=0).fit(norm)
    ks.append(abs(kmeans.score(norm)))

# %%
plt.plot(range(2,12), ks)

plt.show()

# %% [markdown]
# We would put the optimal k as 4. We would hope to see that through the kmeans that words that have similar "contexts" are generally grouped together. However if you look at the actual groupings below we see that this is not actually the case. Perhaps this is because of the fact that I only used a relatively small number of samples (restriction on harware) or because of the fact that the samples were taken at random. The resulting k-means clusters did not give me immediately obvious clusters

# %%
kmeanModel = KMeans(n_clusters=4).fit(norm)
label = kmeanModel.fit_predict(norm)

# %%
clusteranalyze = pd.DataFrame()
clusteranalyze['label'] = label
clusteranalyze['word'] = words
clusteranalyze
# Out:
#     label                       word
# 0       3       v._Jeppesen_Dataplan
# 1       2                 K._Schrute
# 2       1  Supply_Chain_Demand_Chain
# 3       3                   Kincaide
# 4       0           PINK_SHEETS_BMGP
# 5       3              RangeMax_NEXT
# 6       0            Antofagasta_Plc
# 7       2                   Glaubman
# 8       0                   Brondeau
# 9       1         Strategic_Analysis
# 10      0   Yocha_Dehe_Wintun_Nation
# 11      0                  holloware
# 12      1     Corporation_OTCBB_SMWF
# 13      1              repressurized
# 14      2                     Sopron
# 15      3                   Straddie
# 16      2               Rosa_Mystica
# 17      3           David_Fiuczynski
# 18      1            Michael_O'Boyce
# 19      3                     soaked
# 20      2                        Apt
# 21      2                    Allaham
# 22      2                      Kraay
# 23      2                    cleanly
# ...

# %%
clusteranalyze[clusteranalyze.label==0]
# Out:
#     label                      word
# 4       0          PINK_SHEETS_BMGP
# 6       0           Antofagasta_Plc
# 8       0                  Brondeau
# 10      0  Yocha_Dehe_Wintun_Nation
# 11      0                 holloware
# 29      0         unanchored_mobile
# 37      0   Infielder_Carlos_Baerga
# 39      0       wastewater_effluent
# 48      0            Aerial_Mapping
# 49      0                Joe_Beimel
# 51      0    www.verizon.net_fiostv
# 61      0          spewed_profanity
# 69      0             Tatweer_Dubai
# 75      0                 SupplyPro
# 76      0                ACCELERADE
# 77      0     www.sptimes.com_blogs
# 79      0       coach_Ted_Monachino
# 81      0                       LMY
# 85      0        By_FABIOLA_SANCHEZ
# 86      0                     PCATS
# 91      0        TGC_Industries_Inc

# %%
clusteranalyze[clusteranalyze.label==1]
# Out:
#     label                              word
# 2       1         Supply_Chain_Demand_Chain
# 9       1                Strategic_Analysis
# 12      1            Corporation_OTCBB_SMWF
# 13      1                     repressurized
# 18      1                   Michael_O'Boyce
# 27      1                       THE_SAVAGES
# 30      1                     Terra_Futuros
# 31      1                              CIME
# 33      1                             ##bar
# 36      1                       baseline_Hb
# 38      1                       Works_MoPPW
# 40      1         conwert_Immobilien_Invest
# 41      1   store_www.futureshop.ca_Burnaby
# 43      1                     Charles_Shaar
# 50      1                 bacterium_infects
# 53      1                           Differs
# 57      1  PRONTO_Distribution_Requirements
# 59      1                     Sport_Utility
# 66      1                         LG_Sentio
# 68      1              SOFTWARE_CORPORATION
# ...

# %%
clusteranalyze[clusteranalyze.label==2]
# Out:
#     label                             word
# 1       2                       K._Schrute
# 7       2                         Glaubman
# 14      2                           Sopron
# 16      2                     Rosa_Mystica
# 20      2                              Apt
# 21      2                          Allaham
# 22      2                            Kraay
# 23      2                          cleanly
# 25      2                         Gajewski
# 26      2                          Cathlyn
# 35      2  McKibben_jmckibben@poststar.com
# 47      2                        Jolicoeur
# 55      2                Kathleen_Calligan
# 56      2                             Roee
# 60      2                          inboxes
# 63      2                            Bakaa
# 64      2                        Yakub_Ali
# 65      2                Residency_Program
# 67      2                             tong
# 70      2            Email_ir@csisolar.com
# 97      2                            Bergh
# ...

# %%
clusteranalyze[clusteranalyze.label==3]
# Out:
#     label                       word
# 0       3       v._Jeppesen_Dataplan
# 3       3                   Kincaide
# 5       3              RangeMax_NEXT
# 15      3                   Straddie
# 17      3           David_Fiuczynski
# 19      3                     soaked
# 24      3                  DIAL_IN_#
# 28      3            Gregg_Breinberg
# 32      3    jellied_cranberry_sauce
# 34      3         waterproof_ponchos
# 42      3               antagonistic
# 44      3        Chandigarh_Ludhiana
# 45      3               evolutionary
# 46      3                 VanArsdall
# 52      3        flirtatious_glances
# 54      3            underemphasized
# 58      3              Tracy_Lampley
# 62      3           piano_vibraphone
# 71      3                   Mutijulu
# 72      3              Ashish_Pandey
# 74      3            Southwesterners
# 84      3               chyawanprash
# 88      3                      Peale
# 93      3  Mildred_Snitzer_Orchestra
# ...

# %% [markdown]
# Q7: What loss function does the skipgram model use and briefly describe what this function is minimizing

# %% [markdown]
# We know that the skipgram model tries to maximize the log probability of a word given some context. Through this we know that we minimize the negative log probability

# %% [markdown]
# I will choose a fictional novel. Probably an young adult fiction along the lines of percy jackson. HOwever, If we do have to pick one from the thing I would pick the nltk corpus

# %%
import nltk
from nltk import word_tokenize
from nltk import tokenize
from nltk.corpus import brown 
from nltk.corpus import inaugural
from sklearn.manifold import TSNE

# %%
#nltk.download('inaugural')
nltk.download('brown')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\Mike\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Mike\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
# The Inaugural corpus:
words = inaugural.words()
print(len(words))

#unique words 
unique = set()
for i in words:
    unique.add(i)
unique = list(unique)
# Out:
# 145735

# %%
gensim.models.KeyedVectors.load_word2vec_format('brown', binary=True)
# Out:
#   File "<ipython-input-33-8194dcfb3be6>", line 1
#     gensim.models.KeyedVectors.load_word2vec_format('C:\Users\Mike\190INFO\lab6\brown', binary=True)
#                                                    ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
sentences = gensim.models.word2vec.PathLineSentences('C:\\Users\\Mike\\190INFO\\lab6\\inaugural')
model = gensim.models.Word2Vec(sentences, min_count=1, size = 16, window=7)



vectors=[] 
for i in unique:
    vectors.append(model.wv[i])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-39-200b25c3fb41> in <module>()
#       1 sentences = gensim.models.word2vec.PathLineSentences('C:\\Users\\Mike\\190INFO\\lab6\\inaugural')
# ----> 2 model = gensim.models.Word2Vec(sentences, min_count=1, size = 16, window=7)
#       3
#       4 vectors=[]
#       5 for i in unique:
#
# ~\Anaconda3\lib\site-packages\gensim\models\word2vec.py in __init__(self, sentences, size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, cbow_mean, hashfxn, iter, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks)
#     525             batch_words=batch_words, trim_rule=trim_rule, sg=sg, alpha=alpha, window=window, seed=seed,
#     526             hs=hs, negative=negative, cbow_mean=cbow_mean, min_alpha=min_alpha, compute_loss=compute_loss,
# ...

# %%
url = "http://www.gutenberg.org/files/1399/1399-0.txt" ## Your raw text file location 
resp = urlopen(url)
raw = resp.read().decode('utf8')
firstlook = tokenize.sent_tokenize(raw)

pattern = r'''(?x)  # set flag to allow verbose regexps
(?:[A-Z]\.)+        # abbreviations, e.g. U.S.A.
|\w+(?:[-']\w+)*    # words with optional internal hyphens
|\$?\d+(?:\.\d+)?   # currency, e.g. $12.80 
|\.\.\.             # elipses
|[.,;"'?()-_`]      # these are separate tokens
'''
#print(nltk.regexp_tokenize(raw,pattern))
tokenized_raw =" ".join( nltk.regexp_tokenize(raw,pattern))
tokenized_raw=tokenize.sent_tokenize(tokenized_raw)

nopunct=[]
for sent in tokenized_raw:
    a=[w for w in sent.split() if w not in string.punctuation]
    nopunct.append(" ".join(a))
#create a set of stopwords
tok_corp= [nltk.word_tokenize(sent) for sent in nopunct]

### creating a list of unique words 

combined_list=[" ".join(w) for w in tok_corp]
unique_list=[]
for sent in combined_list:
    unique_list.append([w for w in sent.split()])
unique_list=list(set([item for sublist in unique_list for item in sublist]))

unique_words=unique_list

### Its just one single command
model = gensim.models.Word2Vec(tok_corp, min_count=1, size = 16, window=7)

## Extracting the respective vectors corresponding to the words

vector_list=[] ## n by d matrix contaiing words and their respective vectors
for word in unique_words:
    vector_list.append(model[word])
# Out:
# C:\Users\Mike\Anaconda3\lib\site-packages\ipykernel_launcher.py:41: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
data_reduction = TSNE().fit_transform(vector_list)
